# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya8542/FMML-LAB/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 10:11:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  73.3MB/s    in 0.9s
#
# 2024-03-28 10:11:48 (73.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 379    1611.04488v4  We propose a method to optimize the representa...  stat
# 37892   1103.2670v1  The estimation of asset return distributions i...  stat
# 7009   1709.01006v1  Recently, there has been a growing interest in...  stat
# 6102   1607.03475v1  The GMM (generalized min-max) kernel was recen...  stat
# 3472   1708.00069v1  Unsupervised learning techniques in computer v...  stat
# ...             ...                                                ...   ...
# 11137   1410.0908v1  The logistic normal distribution has recently ...  stat
# 34613  1706.05719v1  This master thesis describes an algorithm for ...    cs
# 7782   1803.03672v1  Machine learning is often used in competitive ...    cs
# 32584   1404.4108v2  Consider a Machine Learning Service Provider (...    cs
# 31424  1803.03420v1  Brightfield and fluorescent imaging of whole b...    cs
#
#                                                    title  year  \
# 379    Generative Models and Model Criticism via Opti...  2016
# 37892  Constrained Mixture Models for Asset Returns M...  2011
# 7009   Learning Implicit Generative Models Using Diff...  2017
# 6102     Nystrom Method for Approximating the GMM Kernel  2016
# 3472   Learning Robust Representations for Computer V...  2017
# ...                                                  ...   ...
# 11137              Probit Normal Correlated Topic Models  2014
# 34613  Towards the Improvement of Automated Scientifi...  2017
# 7782   Competitive Machine Learning: Best Theoretical...  2018
# 32584                        Representation as a Service  2014
# 31424  Robust Landmark Detection for Alignment of Mou...  2018
#
#                                                 keywords
# 379    [representation, distinguishability, probabili...
# 37892  [estimation, distributions, determining, strat...
# 7009   [parametric, stochastic, optimization, statist...
# 6102   [similarity, demonstrated, effective, consiste...
# 3472   [unsupervised, techniques, representations, di...
# ...                                                  ...
# 11137  [distribution, transformation, multivariate, v...
# 34613  [describes, algorithm, automated, categorizati...
# 7782   [competitive, scenarios, participants, assumpt...
# 32584  [challenge, identified, dimensionality, knowle...
# 31424  [brightfield, fluorescent, sectioning, efficie...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 379      [representation, distinguishability, probabili...
# 37892    [estimation, distributions, determining, strat...
# 7009     [parametric, stochastic, optimization, statist...
# 6102     [similarity, demonstrated, effective, consiste...
# 3472     [unsupervised, techniques, representations, di...
#                                ...
# 22641    [clustering, partition, objective, clustering,...
# 24309    [segmentation, conventionally, conventional, i...
# 30702    [segmentation, segmentation, traditionally, se...
# 11942    [ergodicity, presented, methodology, approache...
# 9153     [challenges, multimedia, information, retrieva...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8803 words.
# Out of those 4588 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="632f3de4-cbdb-47bd-bd83-c207f5e37885" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("632f3de4-cbdb-47bd-bd83-c207f5e37885")) {                    Plotly.newPlot(                        "632f3de4-cbdb-47bd-bd83-c207f5e37885",                        [{"x":["generative","discrepancy","estimated","distinguished","probability","reference","maximizing","distinguishability","performance","indication","discriminator","statistical","classifier","particularly","realistic","individual","optimized","adversarial","distributions","interpretable","criticism","representation","unsupervised","accounting","modelling","strategies","estimation","framework","constrained","description","expectation","constraints","determining","differentiable","stochastic","distribution","significantly","statistics","experimentally","optimization","cardinality","parameters","motivated","effectively","smoothing","graphical","classical","neighbour","undirected","independent","parametric","potentials","comparable","computing","approximating","experiments","extensive","similarity","effective","demonstrated","typically","competitor","substantially","nonlinear","accuracies","consistent","empirically","algorithm","literature","contributions","foreground","subspaces","approaches","interpretation","background","dimensional","development","techniques","representations","clustering","obscuring","understanding","increasing","enforcing","computational","efficient","implementation","vectorized","separable","underlying","multidimensional","volumetric","applications","arbitrary","structure","processing","preexisting","algorithms","principled","expresses","considerably","unfortunately","unavailable","equations","solutions","efficiency","efficiently","incorporating","buildings","temperatures","approximate","implemented","applicability","especially","differential","behaviour","predicting","inference","generated","application","estimates","demonstrate","superiority","optimizers","carefully","iterative","newtonian","establishing","reproducing","principles","derivation","connection","heuristic","potential","hypothesis","numerical","providing","quadratic","formulation","equivalent","furthermore","partitioning","mechanics","associated","perspective","mathematical","quadratically","generalized","euclidean","established","embedding","significant","particular","similarities","preserves","formulate","exploiting","embeddings","signature","personalized","appearance","uncovered","important","additional","properties","histories","critically","attributes","variation","predictors","considered","factorization","incorporate","influence","discovering","selection","information","recommendation","alleviate","extracted","dimensions","preferences","qualitatively","recommender","performing","introduces","sufficient","explicitly","formulating","generating","classification","adaptation","unconstrained","reconstruct","categorical","instances","transferred","alternative","improvement","challenging"],"y":[126,14,51,6,171,54,30,1,890,4,13,161,148,71,55,129,54,99,126,30,4,364,148,10,48,103,193,545,73,72,25,154,35,28,129,199,275,69,51,329,5,252,60,131,14,64,97,7,17,114,37,9,105,118,16,583,171,132,272,116,103,3,28,64,21,78,63,812,132,43,20,12,423,66,65,197,123,334,249,144,1,157,104,14,265,402,119,3,13,122,13,14,427,105,312,298,1,595,19,3,35,33,6,28,164,155,181,53,15,1,97,114,33,120,24,35,60,206,175,238,78,565,28,4,35,84,1,19,9,26,7,40,58,167,52,86,90,29,72,58,181,25,9,125,58,64,2,77,33,43,117,233,272,37,18,60,84,91,10,14,69,3,337,121,225,3,10,78,56,13,130,33,52,54,35,154,699,27,30,105,39,33,19,17,89,81,67,74,13,108,541,60,23,37,11,110,16,101,124,236],"type":"bar"},{"x":["generative","discrepancy","estimate ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4588,), (4588, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7891666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Meta</span> <span style=''>Path</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Collective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.3053221288515406);'>Information</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Collective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>intensively</span> <span style=''>studied</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>impact</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style=''>web</span> <span style=''>mining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bioinformatics</span> <span style=''>and</span> <span style=''>citation</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Collective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>of</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style=''>linked</span> <span style=''>objects</span> <span style=''>whose</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>and</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>studying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>networks</span> <span style=''>which</span> <span style=''>involves</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style=''>data</span> <span style=''>objects</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>interconnected</span> <span style=''>by</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style=''>links</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>Intuitively</span> <span style=''>two</span> <span style=''>objects</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>if</span> <span style=''>they</span> <span style=''>are</span> <span style=''>linked</span> <span style=''>by</span> <span style=''>many</span> <span style=''>paths</span> <span style=''>in</span> <span style=''>the</span> <span style=''>network</span> <span style=''>However</span> <span style=''>most</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>mixtures</span> <span style=''>as</span> <span style=''>emission</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <span style=''>(HMM)</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>account</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>The</span> <span style=''>emission</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>often</span> <span style=''>supposed</span> <span style=''>to</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>family</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style=''>modeling</span> <span style=''>where</span> <span style=''>the</span> <span style=''>emission</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>get</span> <span style=''>a</span> <span style=''>higher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>For</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialisation</span> <span style=''>step</span> <span style=''>starting</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>method</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>them</span> <span style=''>into</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>states</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>Three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>to</span> <span style=''>be</span> <span style=''>combined</span> <span style=''>are</span> <span style='background-color:rgba(255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Latent</span> <span style=''>Maximum</span> <span style=''>Entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principle</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.31923890063424953);'>statistical</span> <span style=''>learning</span> <span style=''>paradigm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>we</span> <span style=''>have</span> <span style=''>proposed</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>maximum</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>(LME)</span> <span style=''>LME</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>both</span> <span style=''>from</span> <span style=''>Jaynes</span> <span style=''>maximum</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>and</span> <span style=''>from</span> <span style=''>standard</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4552845528455285);'>likelihood</span> <span style=''>estimationWe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>LME</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>BY</span> <span style=''>deriving</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style=''>machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>show</span> <span style=''>how</span> <span style=''>robust</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>new</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style=''>developedOur</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>LME</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>yields</span> <span style=''>better</span> <span style=''>results</span> <span style=''>than</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4552845528455285);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.31343283582089554);'>inferring</span> <span style=''>hidden</span> <span style=''>units</span> <span style=''>from</span> <span style=''>small</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>Boosting</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>Boosting</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>AdaBoost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>work</span> <span style=''>with</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>required</span> <span style=''>training</span> <span style=''>time</span> <span style=''>and</span> <span style=''>improves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalisation</span> <span style=''>We</span> <span style=''>draw</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inspiration</span> <span style=''>from</span> <span style=''>Transfer</span> <span style=''>of</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>start</span> <span style=''>up</span> <span style=''>time</span> <span style=''>to</span> <span style=''>training</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>Ensemble</span> <span style=''>member</span> <span style=''>We</span> <span style=''>show</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>that</span> <span style=''>outlines</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preliminary</span> <span style=''>results</span> <span style=''>on</span> <span style=''>some</span> <span style=''>common</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>Boosting</span> <span style=''>brings</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>Ensemble</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13876106194690266)
# 	knowledge (0.12)
# 	segmentation (0.06336283185840708)
# 	architecture (0.08920353982300885)
# 	processing (0.10548672566371682)
# 	representation (0.1288495575221239)
# 	information (0.24743362831858406)
# 	detection (0.11858407079646018)
# 	recognition (0.1295575221238938)
# 	convolutional (0.13238938053097346)
#
# Some Statistics words are:
# 	theoretical (0.14936708860759493)
# 	stochastic (0.13772151898734178)
# 	variables (0.13670886075949368)
# 	statistical (0.1579746835443038)
# 	distribution (0.17974683544303796)
# 	estimation (0.17772151898734176)
# 	dimensional (0.18177215189873416)
# 	algorithm (0.40354430379746836)
# 	inference (0.1929113924050633)
# 	regression (0.1918987341772152)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="38e70681-164c-4b60-9ef3-eced4ca43609" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38e70681-164c-4b60-9ef3-eced4ca43609")) {                    Plotly.newPlot(                        "38e70681-164c-4b60-9ef3-eced4ca43609",                        [{"x":["generative","discrepancy","estimated","distinguished","probability","reference","maximizing","distinguishability","performance","indication","discriminator","statistical","classifier","particularly","realistic","individual","optimized","adversarial","distributions","interpretable","criticism","representation","unsupervised","accounting","modelling","strategies","estimation","framework","constrained","description","expectation","constraints","determining","differentiable","stochastic","distribution","significantly","statistics","experimentally","optimization","cardinality","parameters","motivated","effectively","smoothing","graphical","classical","neighbour","undirected","independent","parametric","potentials","comparable","computing","approximating","experiments","extensive","similarity","effective","demonstrated","typically","competitor","substantially","nonlinear","accuracies","consistent","empirically","algorithm","literature","contributions","foreground","subspaces","approaches","interpretation","background","dimensional","development","techniques","representations","clustering","obscuring","understanding","increasing","enforcing","computational","efficient","implementation","vectorized","separable","underlying","multidimensional","volumetric","applications","arbitrary","structure","processing","preexisting","algorithms","principled","expresses","considerably","unfortunately","unavailable","equations","solutions","efficiency","efficiently","incorporating","buildings","temperatures","approximate","implemented","applicability","especially","differential","behaviour","predicting","inference","generated","application","estimates","demonstrate","superiority","optimizers","carefully","iterative","newtonian","establishing","reproducing","principles","derivation","connection","heuristic","potential","hypothesis","numerical","providing","quadratic","formulation","equivalent","furthermore","partitioning","mechanics","associated","perspective","mathematical","quadratically","generalized","euclidean","established","embedding","significant","particular","similarities","preserves","formulate","exploiting","embeddings","signature","personalized","appearance","uncovered","important","additional","properties","histories","critically","attributes","variation","predictors","considered","factorization","incorporate","influence","discovering","selection","information","recommendation","alleviate","extracted","dimensions","preferences","qualitatively","recommender","performing","introduces","sufficient","explicitly","formulating","generating","classification","adaptation","unconstrained","reconstruct","categorical","instances","transferred","alternative","improvement","challenging","considers","regularize","unannotated","sentences","decomposition","advantages","maximization","languages","combining","discriminative","dependency","maximizes","surprising","sequentially","simulations","covariates","introduced","dispersion","following","simultaneously","historical","integrate","predictive","environment","inclusion","asymptotically","synthetic","bipartite","competitive","allocation","benchmark","heuristics","addresses","resources","available","platforms","contracts","dynamically","tractable","presenting","modifications","dependence","differentially","simulated","prediction","optimally","constraint","regression","revealing","coefficient","consolidating","conducted","quantities","unbounded"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	misspecified
# 	lindenstrauss
# 	fmathcalx
# 	rightarrow
# 	asynchrony
# 	factorizes
# 	representer
# 	collinearity
# 	variationally
# 	recombines
# 	reformulating
# 	preselected
# 	regressions
# 	metabolites
# 	cancellation
# 	nomination
# 	chemicals
# 	ellipsoidal
# 	statisticians
# 	personalizing
# Some words which never appear in Statistics papers:
# 	uncovered
# 	unannotated
# 	contracts
# 	quadrotor
# 	annotating
# 	discarded
# 	unimportant
# 	tracklets
# 	starcraft
# 	programmers
# 	deformation
# 	attractor
# 	elections
# 	reflection
# 	recommenders
# 	demography
# 	rationales
# 	particularities
# 	mediterranean
# 	necessitate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0452524514282233e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7358333333333333
